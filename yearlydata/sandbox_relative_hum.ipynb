# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

a=17015010

mpl.rcParams['figure.figsize'] = 12, 8
s='estaciones/%s.txt' % a
df = pd.read_csv(s, index_col=False,names='xabcdefghijkl')
df=df.convert_objects(convert_numeric=True)
w=df.mean(axis=0)
dev=df.std(axis=0)
plt.errorbar(np.arange(1,13),w,yerr=dev,fmt='o', ecolor='r')
plt.xlabel('Month')
plt.ylabel('Mean Rel. Humidity ($\%$)')
xlabels=['','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
plt.xticks(range(0,13),xlabels)
s1='estaciones/%sf.txt' % a
df1 = pd.read_csv(s1)
syr=int(df1.columns[0])
eyr=syr+len(df1)/12
sn='estaciones/%sn.txt' % a
with open (sn, "r") as myfile:
    a=myfile.read().replace('\n', '').replace('LA-','GUAJIRA-').replace('SAN-','S_ANDRES-').replace('NORTE-','N_SANT-').replace('HUIGUAJIRA-','HUILA-')
x1,x2,y1,y2 = plt.axis()
plt.axis((0,13,y1,y2))
plt.title("Average Rel. Humidity per Month (%s-%s): "% (syr,eyr-1)+a)

# %%
print dev[0:]
# Out:
# a    1.924604
# b    1.962142
# c    1.991051
# d    2.628899
# e    2.336053
# f    2.019651
# g    1.599075
# h    2.284251
# i    2.229282
# j    2.015095
# k    2.605356
# l    2.164189
# dtype: float64

# %%
mpl.rcParams['figure.figsize'] = 24, 30

# %%
dfnew=pd.read_csv('desv.txt', index_col=False,names='xabcdefghijkl')
dfkey=pd.read_csv('clave.csv', index_col=False,names='abcde')

# %%
for i in range(1,13):
    plt.subplot(4, 3,i)
    plt.scatter(-dfkey.d,dfkey.c,s=dfnew[[i]]*40)

# %%
dfnew[[0]]
# Out:
#                             x
# 0                     SAN-SAN
# 1             SAN-PROVIDENCIA
# 2             MAGDALENA-SANTA
# 3           BOLIVAR-CARTAGENA
# 4           ATLANTICO-SOLEDAD
# 5                 LA-RIOHACHA
# 6            CESAR-VALLEDUPAR
# 7               SUCRE-COROZAL
# 8            CORDOBA-MONTERIA
# 9            ANTIOQUIA-CAREPA
# 10  SANTANDER-BARRANCABERMEJA
# 11          SANTANDER-LEBRIJA
# 12               NORTE-CUCUTA
# 13         ANTIOQUIA-MEDELLIN
# 14         ANTIOQUIA-RIONEGRO
# 15           CALDAS-MANIZALES
# 16          RISARALDA-PEREIRA
# 17            QUINDIO-ARMENIA
# 18              TOLIMA-IBAGUE
# 19              BOGOTA-BOGOTA
# 20              VALLE-PALMIRA
# 21              CAUCA-POPAYAN
# 22                HUILA-NEIVA
# 23           NARINO-CHACHAGUI
# 24              NARINO-ALDANA
# 25                NORTE-OCANA
# 26               CHOCO-QUIBDO
# 27         VALLE-BUENAVENTURA
# 28              CHOCO-CONDOTO
# 29              ARAUCA-ARAUCA
# 30             VICHADA-PUERTO
# 31         META-VILLAVICENCIO
# 32           VICHADA-CUMARIBO
# 33           AMAZONAS-LETICIA
